# %% [markdown]
# <a href="https://colab.research.google.com/github/tnewtont/Detecting_Palm_Oil_Plantations_Neural_Networks/blob/main/WiDS_Project_VGG19_gridsearch_ipynb_(0_9701480958681058).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Training With VGG19 and Grid Search**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter, ImageEnhance
import json
import pickle
import io, os
import gzip
from google.colab import files
from tensorflow.keras import datasets, layers, models
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import VGG16
from sklearn.metrics import roc_auc_score
import tensorflow as tf
import random
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn.metrics import recall_score, f1_score, precision_recall_curve, average_precision_score, auc, roc_curve
import seaborn as sns
from keras import regularizers
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GaussianNoise, RandomFlip, RandomZoom, RandomRotation, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import HeNormal
import tensorflow.keras.backend
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Load our pickled training set
with gzip.open('/content/drive/MyDrive/images_labels.pickle.gz', 'rb') as f:
  images, labels = pickle.load(f)

# %% [markdown]
# We will train-test split our dataset two times so that we have a training and a validation dataset.

# %%
xtrain, xtest, ytrain, ytest = train_test_split(images, labels, test_size = 0.2, random_state = 42, stratify = labels)

# %%
xtrain, xval, ytrain, yval = train_test_split(xtrain, ytrain, test_size = 0.2, random_state = 42, stratify = ytrain)

# %%
# Using tf.data.AUTOTUNE optimizes the performance of our datasets while training
train_dataset = tf.data.Dataset.from_tensor_slices((xtrain, ytrain)).batch(32).prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((xval, yval)).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
# Load our pickled holdout dataset
with gzip.open('/content/drive/MyDrive/holdout_images_labels.pickle.gz', 'rb') as f:
    ho_images_arr, ho_labels_arr = pickle.load(f)

# %%
ho_dataset = (ho_images_arr, ho_labels_arr)

# %%
x_holdout, y_holdout = ho_dataset

# %% [markdown]
# We will initialize a custom callback that keeps track of several metrics as our model is training.

# %%
class PrecisionRecallHoldoutCallback(tf.keras.callbacks.Callback):
    def __init__(self, holdout_data):
        self.holdout_data = holdout_data  # Holdout data (X, y)
        self.precision_0 = []
        self.recall_0 = []
        self.f1_0 = []  # F1 score for Class 0
        self.precision_1 = []
        self.recall_1 = []
        self.f1_1 = []  # F1 score for Class 1
        self.roc_auc_scores = []  # ROC-AUC scores across epochs
        self.ap_scores = [] # AP scores across epochs

    def on_epoch_end(self, epoch, logs=None):
        x_holdout, y_holdout = self.holdout_data
        predictions = self.model.predict(x_holdout).ravel() # Flatten out
        predictions_binary = (predictions > 0.5).astype(int)  # Convert probabilities to binary predictions

        # Compute metrics for Class 0
        precision_0 = precision_score(y_holdout, predictions_binary, pos_label=0)
        recall_0 = recall_score(y_holdout, predictions_binary, pos_label=0)
        f1_0 = f1_score(y_holdout, predictions_binary, pos_label=0)

        # Compute metrics for Class 1
        precision_1 = precision_score(y_holdout, predictions_binary, pos_label=1)
        recall_1 = recall_score(y_holdout, predictions_binary, pos_label=1)
        f1_1 = f1_score(y_holdout, predictions_binary, pos_label=1)

        # Compute ROC-AUC score
        roc_auc = roc_auc_score(y_holdout, predictions)
        # Compute Average Precision (AP) score
        ap_score = average_precision_score(y_holdout, predictions)

        # Log metrics
        print(f"\nEpoch {epoch + 1}: Holdout Precision (Class 0) = {precision_0:.4f}, Recall (Class 0) = {recall_0:.4f}, F1 (Class 0) = {f1_0:.4f}")
        print(f"Epoch {epoch + 1}: Holdout Precision (Class 1) = {precision_1:.4f}, Recall (Class 1) = {recall_1:.4f}, F1 (Class 1) = {f1_1:.4f}")
        print(f"Epoch {epoch + 1}: Holdout ROC-AUC Score = {roc_auc:.4f}, Average Precision (AP) Score = {ap_score:.4f}")

        # Append metrics to lists
        self.precision_0.append(precision_0)
        self.recall_0.append(recall_0)
        self.f1_0.append(f1_0)
        self.precision_1.append(precision_1)
        self.recall_1.append(recall_1)
        self.f1_1.append(f1_1)
        self.roc_auc_scores.append(roc_auc)
        self.ap_scores.append(ap_score)

        # Optionally store metrics in logs for further analysis
        logs['holdout_precision_0'] = precision_0
        logs['holdout_recall_0'] = recall_0
        logs['holdout_f1_0'] = f1_0
        logs['holdout_precision_1'] = precision_1
        logs['holdout_recall_1'] = recall_1
        logs['holdout_f1_1'] = f1_1
        logs['holdout_roc_auc'] = roc_auc
        logs['holdout_ap'] = ap_score

# %% [markdown]
# Here, we are utilizing VGG19, which is a pre-trained model. In particular, we will perform a grid search of two hyperparameters: L2 regularization, which gets applied to the final dense layer, and the number of epochs. Besides L2 regularization, using He / Kaiming normalization, dropouts, and lower learning rate helps prevent our model from overfitting.

# %%
l2_values = [0.03851, 0.03852, 0.03853, 0.03854, 0.03855]
epoch_values = [3, 4]
best_model_path = None
best_score = None
best_params = None
best_history = None
best_metrics = None
results = []

for l2 in l2_values:
    for epochs in epoch_values:
        print(f"Testing L2 = {l2}, epochs = {epochs}")

        # Define model
        vgg19 = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
        for layer in vgg19.layers:
            layer.trainable = False

        fl = Flatten()(vgg19.layers[-1].output)
        dl1 = Dense(300, activation='relu', kernel_initializer=HeNormal())(fl)
        dropout1 = Dropout(0.4)(dl1)
        dl2 = Dense(200, activation='relu', kernel_initializer=HeNormal())(dropout1)
        dropout2 = Dropout(0.3)(dl2)
        dl3 = Dense(100, activation='relu', kernel_initializer=HeNormal())(dropout2)
        dropout3 = Dropout(0.25)(dl3)
        dl4 = Dense(50, activation='relu', kernel_initializer=HeNormal())(dropout3)
        dropout4 = Dropout(0.25)(dl4)
        dl5 = Dense(25, activation='relu', kernel_initializer=HeNormal())(dropout4)
        dropout5 = Dropout(0.2)(dl5)
        ol = Dense(1, activation='sigmoid', kernel_initializer=HeNormal(),
                   kernel_regularizer=regularizers.l2(l2))(dropout5)
        model = Model(inputs=vgg19.input, outputs=ol)

        # Compile
        model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate = 1e-4, weight_decay = 5e-5),
                      loss='binary_crossentropy',
                      metrics=['accuracy', tf.keras.metrics.AUC(name='roc_auc', curve='ROC')])

        # Train
        holdout_callback = PrecisionRecallHoldoutCallback((x_holdout, y_holdout))
        history = model.fit(
            train_dataset,
            epochs=epochs,
            validation_data=val_dataset,
            callbacks=[holdout_callback],
            verbose=1
        )

        # Evaluate
        roc_auc_score_ho = holdout_callback.roc_auc_scores[-1]
        ap_score = holdout_callback.ap_scores[-1]
        f1_class_0 = holdout_callback.f1_0[-1]
        f1_class_1 = holdout_callback.f1_1[-1]
        avg_f1_score = (f1_class_0 + f1_class_1) / 2


        x_holdout, y_holdout = ho_dataset
        predictions = model.predict(x_holdout)
        predictions = (predictions > 0.5).astype(int)

        precision_0 = precision_score(y_holdout, predictions, pos_label=0)
        recall_0 = recall_score(y_holdout, predictions, pos_label=0)

        precision_1 = precision_score(y_holdout, predictions, pos_label=1)
        recall_1 = recall_score(y_holdout, predictions, pos_label=1)

        print(f"L2 = {l2}, epochs = {epochs}: ROC-AUC = {roc_auc_score_ho:.4f}, "
              f"F1 (Class 0) = {f1_class_0:.4f}, F1 (Class 1) = {f1_class_1:.4f}, "
              f"AP score = {ap_score:.4f}, "
              f"Average F1 Score = {avg_f1_score:.4f}")

        # Append results
        results.append({
            'l2': l2,
            'epochs': epochs,
            'roc_auc': roc_auc_score_ho,
            'ap_score': ap_score,
            'f1_class_0': f1_class_0,
            'f1_class_1': f1_class_1,
            'avg_f1_score': avg_f1_score,
            'precision_0': precision_0,
            'recall_0': recall_0,
            'precision_1': precision_1,
            'recall_1': recall_1
        })

        # Track best metrics
        if best_score is None or avg_f1_score > best_score:
            print("\nUpdating best model.\n")
            best_score = avg_f1_score
            best_metrics = [precision_0, recall_0, precision_1, recall_1, f1_class_0, f1_class_1, ap_score]
            best_params = {'l2': l2, 'epochs': epochs}
            best_history = history.history  # Save the training history of the best model
            model.save('wids_gs_best_mod.keras')  # Save the best model

        # Clear session
        tf.keras.backend.clear_session()

# Save results and best history
pd.DataFrame(results).to_csv('wids_gs_results.csv', index=False)
with open('wids_gs_best_train_history.json', 'w') as f:
    json.dump(best_history, f)

print(f"Best parameters: {best_params}")
print(f"Best holdout metrics: Precision_0 = {best_metrics[0]:.4f}, Recall_0 = {best_metrics[1]:.4f}, "
      f"Precision_1 = {best_metrics[2]:.4f}, Recall_1 = {best_metrics[3]:.4f}, "
      f"F1_0 = {best_metrics[4]:.4f}, F1_1 = {best_metrics[5]:.4f}, "
      f"AP score = {best_metrics[6]:.4f}")
# Out:
# Testing L2 = 0.03851, epochs = 3
# Epoch 1/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 11s 146ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.8493, Recall (Class 0) = 0.6419, F1 (Class 0) = 0.7312
# Epoch 1: Holdout Precision (Class 1) = 0.7122, Recall (Class 1) = 0.8861, F1 (Class 1) = 0.7897
# Epoch 1: Holdout ROC-AUC Score = 0.8860, Average Precision (AP) Score = 0.8952
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 76s 235ms/step - accuracy: 0.5596 - loss: 1.4361 - roc_auc: 0.5812 - val_accuracy: 0.6612 - val_loss: 0.6829 - val_roc_auc: 0.7189 - holdout_precision_0: 0.8493 - holdout_recall_0: 0.6419 - holdout_f1_0: 0.7312 - holdout_precision_1: 0.7122 - holdout_recall_1: 0.8861 - holdout_f1_1: 0.7897 - holdout_roc_auc: 0.8860 - holdout_ap: 0.8952
# Epoch 2/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.8929, Recall (Class 0) = 0.7273, F1 (Class 0) = 0.8016
# Epoch 2: Holdout Precision (Class 1) = 0.7699, Recall (Class 1) = 0.9128, F1 (Class 1) = 0.8353
# Epoch 2: Holdout ROC-AUC Score = 0.9206, Average Precision (AP) Score = 0.9363
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 33s 137ms/step - accuracy: 0.5903 - loss: 0.8340 - roc_auc: 0.6374 - val_accuracy: 0.6949 - val_loss: 0.6605 - val_roc_auc: 0.7597 - holdout_precision_0: 0.8929 - holdout_recall_0: 0.7273 - holdout_f1_0: 0.8016 - holdout_precision_1: 0.7699 - holdout_recall_1: 0.9128 - holdout_f1_1: 0.8353 - holdout_roc_auc: 0.9206 - holdout_ap: 0.9363
# Epoch 3/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.9273, Recall (Class 0) = 0.8907, F1 (Class 0) = 0.9087
# Epoch 3: Holdout Precision (Class 1) = 0.8949, Recall (Class 1) = 0.9302, F1 (Class 1) = 0.9122
# Epoch 3: Holdout ROC-AUC Score = 0.9545, Average Precision (AP) Score = 0.9588
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 33s 139ms/step - accuracy: 0.6324 - loss: 0.7468 - roc_auc: 0.6813 - val_accuracy: 0.7392 - val_loss: 0.6202 - val_roc_auc: 0.8034 - holdout_precision_0: 0.9273 - holdout_recall_0: 0.8907 - holdout_f1_0: 0.9087 - holdout_precision_1: 0.8949 - holdout_recall_1: 0.9302 - holdout_f1_1: 0.9122 - holdout_roc_auc: 0.9545 - holdout_ap: 0.9588
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step
# L2 = 0.03851, epochs = 3: ROC-AUC = 0.9545, F1 (Class 0) = 0.9087, F1 (Class 1) = 0.9122, AP score = 0.9588, Average F1 Score = 0.9104
#
# Updating best model.
#
# Testing L2 = 0.03851, epochs = 4
# Epoch 1/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.9768, Recall (Class 0) = 0.5023, F1 (Class 0) = 0.6634
# Epoch 1: Holdout Precision (Class 1) = 0.6650, Recall (Class 1) = 0.9881, F1 (Class 1) = 0.7950
# Epoch 1: Holdout ROC-AUC Score = 0.9388, Average Precision (AP) Score = 0.9314
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 48s 173ms/step - accuracy: 0.5235 - loss: 1.7446 - roc_auc: 0.5328 - val_accuracy: 0.6354 - val_loss: 0.7007 - val_roc_auc: 0.7189 - holdout_precision_0: 0.9768 - holdout_recall_0: 0.5023 - holdout_f1_0: 0.6634 - holdout_precision_1: 0.6650 - holdout_recall_1: 0.9881 - holdout_f1_1: 0.7950 - holdout_roc_auc: 0.9388 - holdout_ap: 0.9314
# Epoch 2/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.9093, Recall (Class 0) = 0.6814, F1 (Class 0) = 0.7790
# Epoch 2: Holdout Precision (Class 1) = 0.7452, Recall (Class 1) = 0.9320, F1 (Class 1) = 0.8282
# Epoch 2: Holdout ROC-AUC Score = 0.9119, Average Precision (AP) Score = 0.9115
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 141ms/step - accuracy: 0.5986 - loss: 0.8896 - roc_auc: 0.6410 - val_accuracy: 0.6744 - val_loss: 0.6799 - val_roc_auc: 0.7462 - holdout_precision_0: 0.9093 - holdout_recall_0: 0.6814 - holdout_f1_0: 0.7790 - holdout_precision_1: 0.7452 - holdout_recall_1: 0.9320 - holdout_f1_1: 0.8282 - holdout_roc_auc: 0.9119 - holdout_ap: 0.9115
# Epoch 3/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.9154, Recall (Class 0) = 0.6860, F1 (Class 0) = 0.7843
# Epoch 3: Holdout Precision (Class 1) = 0.7489, Recall (Class 1) = 0.9366, F1 (Class 1) = 0.8323
# Epoch 3: Holdout ROC-AUC Score = 0.9369, Average Precision (AP) Score = 0.9374
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 142ms/step - accuracy: 0.6121 - loss: 0.7826 - roc_auc: 0.6663 - val_accuracy: 0.7139 - val_loss: 0.6396 - val_roc_auc: 0.7956 - holdout_precision_0: 0.9154 - holdout_recall_0: 0.6860 - holdout_f1_0: 0.7843 - holdout_precision_1: 0.7489 - holdout_recall_1: 0.9366 - holdout_f1_1: 0.8323 - holdout_roc_auc: 0.9369 - holdout_ap: 0.9374
# Epoch 4/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 4: Holdout Precision (Class 0) = 0.9231, Recall (Class 0) = 0.8154, F1 (Class 0) = 0.8659
# Epoch 4: Holdout Precision (Class 1) = 0.8347, Recall (Class 1) = 0.9320, F1 (Class 1) = 0.8807
# Epoch 4: Holdout ROC-AUC Score = 0.9452, Average Precision (AP) Score = 0.9510
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.6390 - loss: 0.7379 - roc_auc: 0.6990 - val_accuracy: 0.7508 - val_loss: 0.6247 - val_roc_auc: 0.8108 - holdout_precision_0: 0.9231 - holdout_recall_0: 0.8154 - holdout_f1_0: 0.8659 - holdout_precision_1: 0.8347 - holdout_recall_1: 0.9320 - holdout_f1_1: 0.8807 - holdout_roc_auc: 0.9452 - holdout_ap: 0.9510
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
# L2 = 0.03851, epochs = 4: ROC-AUC = 0.9452, F1 (Class 0) = 0.8659, F1 (Class 1) = 0.8807, AP score = 0.9510, Average F1 Score = 0.8733
# Testing L2 = 0.03852, epochs = 3
# Epoch 1/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.8643, Recall (Class 0) = 0.8770, F1 (Class 0) = 0.8706
# Epoch 1: Holdout Precision (Class 1) = 0.8751, Recall (Class 1) = 0.8623, F1 (Class 1) = 0.8686
# Epoch 1: Holdout ROC-AUC Score = 0.9117, Average Precision (AP) Score = 0.9395
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 51s 182ms/step - accuracy: 0.5622 - loss: 1.3821 - roc_auc: 0.5852 - val_accuracy: 0.7013 - val_loss: 0.6408 - val_roc_auc: 0.7518 - holdout_precision_0: 0.8643 - holdout_recall_0: 0.8770 - holdout_f1_0: 0.8706 - holdout_precision_1: 0.8751 - holdout_recall_1: 0.8623 - holdout_f1_1: 0.8686 - holdout_roc_auc: 0.9117 - holdout_ap: 0.9395
# Epoch 2/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.8311, Recall (Class 0) = 0.9624, F1 (Class 0) = 0.8919
# Epoch 2: Holdout Precision (Class 1) = 0.9553, Recall (Class 1) = 0.8044, F1 (Class 1) = 0.8734
# Epoch 2: Holdout ROC-AUC Score = 0.9291, Average Precision (AP) Score = 0.9492
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.6148 - loss: 0.7986 - roc_auc: 0.6587 - val_accuracy: 0.6992 - val_loss: 0.6280 - val_roc_auc: 0.7674 - holdout_precision_0: 0.8311 - holdout_recall_0: 0.9624 - holdout_f1_0: 0.8919 - holdout_precision_1: 0.9553 - holdout_recall_1: 0.8044 - holdout_f1_1: 0.8734 - holdout_roc_auc: 0.9291 - holdout_ap: 0.9492
# Epoch 3/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.8358, Recall (Class 0) = 0.9486, F1 (Class 0) = 0.8886
# Epoch 3: Holdout Precision (Class 1) = 0.9406, Recall (Class 1) = 0.8136, F1 (Class 1) = 0.8725
# Epoch 3: Holdout ROC-AUC Score = 0.9099, Average Precision (AP) Score = 0.9341
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.6345 - loss: 0.7372 - roc_auc: 0.6878 - val_accuracy: 0.7439 - val_loss: 0.6086 - val_roc_auc: 0.8119 - holdout_precision_0: 0.8358 - holdout_recall_0: 0.9486 - holdout_f1_0: 0.8886 - holdout_precision_1: 0.9406 - holdout_recall_1: 0.8136 - holdout_f1_1: 0.8725 - holdout_roc_auc: 0.9099 - holdout_ap: 0.9341
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
# L2 = 0.03852, epochs = 3: ROC-AUC = 0.9099, F1 (Class 0) = 0.8886, F1 (Class 1) = 0.8725, AP score = 0.9341, Average F1 Score = 0.8805
# Testing L2 = 0.03852, epochs = 4
# Epoch 1/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.7781, Recall (Class 0) = 0.9403, F1 (Class 0) = 0.8516
# Epoch 1: Holdout Precision (Class 1) = 0.9246, Recall (Class 1) = 0.7319, F1 (Class 1) = 0.8170
# Epoch 1: Holdout ROC-AUC Score = 0.8992, Average Precision (AP) Score = 0.9158
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.5360 - loss: 1.9046 - roc_auc: 0.5500 - val_accuracy: 0.6633 - val_loss: 0.7001 - val_roc_auc: 0.7240 - holdout_precision_0: 0.7781 - holdout_recall_0: 0.9403 - holdout_f1_0: 0.8516 - holdout_precision_1: 0.9246 - holdout_recall_1: 0.7319 - holdout_f1_1: 0.8170 - holdout_roc_auc: 0.8992 - holdout_ap: 0.9158
# Epoch 2/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.7877, Recall (Class 0) = 0.9027, F1 (Class 0) = 0.8412
# Epoch 2: Holdout Precision (Class 1) = 0.8860, Recall (Class 1) = 0.7567, F1 (Class 1) = 0.8162
# Epoch 2: Holdout ROC-AUC Score = 0.8745, Average Precision (AP) Score = 0.9094
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.5912 - loss: 0.8836 - roc_auc: 0.6378 - val_accuracy: 0.6849 - val_loss: 0.6802 - val_roc_auc: 0.7458 - holdout_precision_0: 0.7877 - holdout_recall_0: 0.9027 - holdout_f1_0: 0.8412 - holdout_precision_1: 0.8860 - holdout_recall_1: 0.7567 - holdout_f1_1: 0.8162 - holdout_roc_auc: 0.8745 - holdout_ap: 0.9094
# Epoch 3/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.7528, Recall (Class 0) = 0.9816, F1 (Class 0) = 0.8521
# Epoch 3: Holdout Precision (Class 1) = 0.9736, Recall (Class 1) = 0.6777, F1 (Class 1) = 0.7991
# Epoch 3: Holdout ROC-AUC Score = 0.9035, Average Precision (AP) Score = 0.9271
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.6246 - loss: 0.7819 - roc_auc: 0.6788 - val_accuracy: 0.7129 - val_loss: 0.6478 - val_roc_auc: 0.8011 - holdout_precision_0: 0.7528 - holdout_recall_0: 0.9816 - holdout_f1_0: 0.8521 - holdout_precision_1: 0.9736 - holdout_recall_1: 0.6777 - holdout_f1_1: 0.7991 - holdout_roc_auc: 0.9035 - holdout_ap: 0.9271
# Epoch 4/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 4: Holdout Precision (Class 0) = 0.7935, Recall (Class 0) = 0.9706, F1 (Class 0) = 0.8732
# Epoch 4: Holdout Precision (Class 1) = 0.9622, Recall (Class 1) = 0.7475, F1 (Class 1) = 0.8413
# Epoch 4: Holdout ROC-AUC Score = 0.9167, Average Precision (AP) Score = 0.9353
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 145ms/step - accuracy: 0.6656 - loss: 0.7015 - roc_auc: 0.7257 - val_accuracy: 0.7524 - val_loss: 0.6159 - val_roc_auc: 0.8245 - holdout_precision_0: 0.7935 - holdout_recall_0: 0.9706 - holdout_f1_0: 0.8732 - holdout_precision_1: 0.9622 - holdout_recall_1: 0.7475 - holdout_f1_1: 0.8413 - holdout_roc_auc: 0.9167 - holdout_ap: 0.9353
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
# L2 = 0.03852, epochs = 4: ROC-AUC = 0.9167, F1 (Class 0) = 0.8732, F1 (Class 1) = 0.8413, AP score = 0.9353, Average F1 Score = 0.8573
# Testing L2 = 0.03853, epochs = 3
# Epoch 1/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.9008, Recall (Class 0) = 0.6336, F1 (Class 0) = 0.7439
# Epoch 1: Holdout Precision (Class 1) = 0.7174, Recall (Class 1) = 0.9302, F1 (Class 1) = 0.8101
# Epoch 1: Holdout ROC-AUC Score = 0.9071, Average Precision (AP) Score = 0.9040
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 51s 182ms/step - accuracy: 0.5244 - loss: 1.9339 - roc_auc: 0.5303 - val_accuracy: 0.6575 - val_loss: 0.6957 - val_roc_auc: 0.7243 - holdout_precision_0: 0.9008 - holdout_recall_0: 0.6336 - holdout_f1_0: 0.7439 - holdout_precision_1: 0.7174 - holdout_recall_1: 0.9302 - holdout_f1_1: 0.8101 - holdout_roc_auc: 0.9071 - holdout_ap: 0.9040
# Epoch 2/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.9303, Recall (Class 0) = 0.6006, F1 (Class 0) = 0.7299
# Epoch 2: Holdout Precision (Class 1) = 0.7051, Recall (Class 1) = 0.9550, F1 (Class 1) = 0.8112
# Epoch 2: Holdout ROC-AUC Score = 0.9293, Average Precision (AP) Score = 0.9343
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.5659 - loss: 0.8990 - roc_auc: 0.5960 - val_accuracy: 0.6675 - val_loss: 0.6849 - val_roc_auc: 0.7406 - holdout_precision_0: 0.9303 - holdout_recall_0: 0.6006 - holdout_f1_0: 0.7299 - holdout_precision_1: 0.7051 - holdout_recall_1: 0.9550 - holdout_f1_1: 0.8112 - holdout_roc_auc: 0.9293 - holdout_ap: 0.9343
# Epoch 3/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.9282, Recall (Class 0) = 0.7475, F1 (Class 0) = 0.8281
# Epoch 3: Holdout Precision (Class 1) = 0.7886, Recall (Class 1) = 0.9421, F1 (Class 1) = 0.8586
# Epoch 3: Holdout ROC-AUC Score = 0.9393, Average Precision (AP) Score = 0.9407
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.5993 - loss: 0.7856 - roc_auc: 0.6500 - val_accuracy: 0.7050 - val_loss: 0.6553 - val_roc_auc: 0.7729 - holdout_precision_0: 0.9282 - holdout_recall_0: 0.7475 - holdout_f1_0: 0.8281 - holdout_precision_1: 0.7886 - holdout_recall_1: 0.9421 - holdout_f1_1: 0.8586 - holdout_roc_auc: 0.9393 - holdout_ap: 0.9407
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
# L2 = 0.03853, epochs = 3: ROC-AUC = 0.9393, F1 (Class 0) = 0.8281, F1 (Class 1) = 0.8586, AP score = 0.9407, Average F1 Score = 0.8433
# Testing L2 = 0.03853, epochs = 4
# Epoch 1/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.8848, Recall (Class 0) = 0.8531, F1 (Class 0) = 0.8686
# Epoch 1: Holdout Precision (Class 1) = 0.8582, Recall (Class 1) = 0.8889, F1 (Class 1) = 0.8733
# Epoch 1: Holdout ROC-AUC Score = 0.9297, Average Precision (AP) Score = 0.9437
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 49s 176ms/step - accuracy: 0.5553 - loss: 2.1298 - roc_auc: 0.5751 - val_accuracy: 0.6955 - val_loss: 0.6717 - val_roc_auc: 0.7567 - holdout_precision_0: 0.8848 - holdout_recall_0: 0.8531 - holdout_f1_0: 0.8686 - holdout_precision_1: 0.8582 - holdout_recall_1: 0.8889 - holdout_f1_1: 0.8733 - holdout_roc_auc: 0.9297 - holdout_ap: 0.9437
# Epoch 2/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.8312, Recall (Class 0) = 0.8999, F1 (Class 0) = 0.8642
# Epoch 2: Holdout Precision (Class 1) = 0.8909, Recall (Class 1) = 0.8173, F1 (Class 1) = 0.8525
# Epoch 2: Holdout ROC-AUC Score = 0.9104, Average Precision (AP) Score = 0.9213
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.6059 - loss: 0.8988 - roc_auc: 0.6509 - val_accuracy: 0.7271 - val_loss: 0.6585 - val_roc_auc: 0.7772 - holdout_precision_0: 0.8312 - holdout_recall_0: 0.8999 - holdout_f1_0: 0.8642 - holdout_precision_1: 0.8909 - holdout_recall_1: 0.8173 - holdout_f1_1: 0.8525 - holdout_roc_auc: 0.9104 - holdout_ap: 0.9213
# Epoch 3/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.8457, Recall (Class 0) = 0.9311, F1 (Class 0) = 0.8864
# Epoch 3: Holdout Precision (Class 1) = 0.9234, Recall (Class 1) = 0.8301, F1 (Class 1) = 0.8743
# Epoch 3: Holdout ROC-AUC Score = 0.9402, Average Precision (AP) Score = 0.9407
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.6367 - loss: 0.7867 - roc_auc: 0.6833 - val_accuracy: 0.7529 - val_loss: 0.6140 - val_roc_auc: 0.8186 - holdout_precision_0: 0.8457 - holdout_recall_0: 0.9311 - holdout_f1_0: 0.8864 - holdout_precision_1: 0.9234 - holdout_recall_1: 0.8301 - holdout_f1_1: 0.8743 - holdout_roc_auc: 0.9402 - holdout_ap: 0.9407
# Epoch 4/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 4: Holdout Precision (Class 0) = 0.8506, Recall (Class 0) = 0.9568, F1 (Class 0) = 0.9006
# Epoch 4: Holdout Precision (Class 1) = 0.9507, Recall (Class 1) = 0.8320, F1 (Class 1) = 0.8874
# Epoch 4: Holdout ROC-AUC Score = 0.9324, Average Precision (AP) Score = 0.9453
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 145ms/step - accuracy: 0.7005 - loss: 0.6887 - roc_auc: 0.7608 - val_accuracy: 0.7771 - val_loss: 0.5763 - val_roc_auc: 0.8474 - holdout_precision_0: 0.8506 - holdout_recall_0: 0.9568 - holdout_f1_0: 0.9006 - holdout_precision_1: 0.9507 - holdout_recall_1: 0.8320 - holdout_f1_1: 0.8874 - holdout_roc_auc: 0.9324 - holdout_ap: 0.9453
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
# L2 = 0.03853, epochs = 4: ROC-AUC = 0.9324, F1 (Class 0) = 0.9006, F1 (Class 1) = 0.8874, AP score = 0.9453, Average F1 Score = 0.8940
# Testing L2 = 0.03854, epochs = 3
# Epoch 1/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.8686, Recall (Class 0) = 0.7043, F1 (Class 0) = 0.7779
# Epoch 1: Holdout Precision (Class 1) = 0.7514, Recall (Class 1) = 0.8935, F1 (Class 1) = 0.8163
# Epoch 1: Holdout ROC-AUC Score = 0.8898, Average Precision (AP) Score = 0.9030
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 51s 183ms/step - accuracy: 0.5441 - loss: 1.4990 - roc_auc: 0.5665 - val_accuracy: 0.6733 - val_loss: 0.6973 - val_roc_auc: 0.7301 - holdout_precision_0: 0.8686 - holdout_recall_0: 0.7043 - holdout_f1_0: 0.7779 - holdout_precision_1: 0.7514 - holdout_recall_1: 0.8935 - holdout_f1_1: 0.8163 - holdout_roc_auc: 0.8898 - holdout_ap: 0.9030
# Epoch 2/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.8834, Recall (Class 0) = 0.8209, F1 (Class 0) = 0.8510
# Epoch 2: Holdout Precision (Class 1) = 0.8328, Recall (Class 1) = 0.8916, F1 (Class 1) = 0.8612
# Epoch 2: Holdout ROC-AUC Score = 0.9275, Average Precision (AP) Score = 0.9309
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.6005 - loss: 0.8839 - roc_auc: 0.6460 - val_accuracy: 0.6907 - val_loss: 0.6515 - val_roc_auc: 0.7679 - holdout_precision_0: 0.8834 - holdout_recall_0: 0.8209 - holdout_f1_0: 0.8510 - holdout_precision_1: 0.8328 - holdout_recall_1: 0.8916 - holdout_f1_1: 0.8612 - holdout_roc_auc: 0.9275 - holdout_ap: 0.9309
# Epoch 3/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.9078, Recall (Class 0) = 0.8044, F1 (Class 0) = 0.8530
# Epoch 3: Holdout Precision (Class 1) = 0.8244, Recall (Class 1) = 0.9183, F1 (Class 1) = 0.8688
# Epoch 3: Holdout ROC-AUC Score = 0.9465, Average Precision (AP) Score = 0.9467
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.6253 - loss: 0.7486 - roc_auc: 0.6874 - val_accuracy: 0.7266 - val_loss: 0.6354 - val_roc_auc: 0.7959 - holdout_precision_0: 0.9078 - holdout_recall_0: 0.8044 - holdout_f1_0: 0.8530 - holdout_precision_1: 0.8244 - holdout_recall_1: 0.9183 - holdout_f1_1: 0.8688 - holdout_roc_auc: 0.9465 - holdout_ap: 0.9467
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
# L2 = 0.03854, epochs = 3: ROC-AUC = 0.9465, F1 (Class 0) = 0.8530, F1 (Class 1) = 0.8688, AP score = 0.9467, Average F1 Score = 0.8609
# Testing L2 = 0.03854, epochs = 4
# Epoch 1/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.8083, Recall (Class 0) = 0.8981, F1 (Class 0) = 0.8508
# Epoch 1: Holdout Precision (Class 1) = 0.8853, Recall (Class 1) = 0.7870, F1 (Class 1) = 0.8333
# Epoch 1: Holdout ROC-AUC Score = 0.9028, Average Precision (AP) Score = 0.9109
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.5478 - loss: 1.5674 - roc_auc: 0.5603 - val_accuracy: 0.6749 - val_loss: 0.6614 - val_roc_auc: 0.7372 - holdout_precision_0: 0.8083 - holdout_recall_0: 0.8981 - holdout_f1_0: 0.8508 - holdout_precision_1: 0.8853 - holdout_recall_1: 0.7870 - holdout_f1_1: 0.8333 - holdout_roc_auc: 0.9028 - holdout_ap: 0.9109
# Epoch 2/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.8493, Recall (Class 0) = 0.8329, F1 (Class 0) = 0.8410
# Epoch 2: Holdout Precision (Class 1) = 0.8360, Recall (Class 1) = 0.8522, F1 (Class 1) = 0.8440
# Epoch 2: Holdout ROC-AUC Score = 0.9098, Average Precision (AP) Score = 0.9310
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.5817 - loss: 0.9116 - roc_auc: 0.6212 - val_accuracy: 0.7065 - val_loss: 0.6523 - val_roc_auc: 0.7671 - holdout_precision_0: 0.8493 - holdout_recall_0: 0.8329 - holdout_f1_0: 0.8410 - holdout_precision_1: 0.8360 - holdout_recall_1: 0.8522 - holdout_f1_1: 0.8440 - holdout_roc_auc: 0.9098 - holdout_ap: 0.9310
# Epoch 3/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.9203, Recall (Class 0) = 0.7741, F1 (Class 0) = 0.8409
# Epoch 3: Holdout Precision (Class 1) = 0.8051, Recall (Class 1) = 0.9330, F1 (Class 1) = 0.8643
# Epoch 3: Holdout ROC-AUC Score = 0.9422, Average Precision (AP) Score = 0.9581
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.6251 - loss: 0.7508 - roc_auc: 0.6757 - val_accuracy: 0.7150 - val_loss: 0.6354 - val_roc_auc: 0.7810 - holdout_precision_0: 0.9203 - holdout_recall_0: 0.7741 - holdout_f1_0: 0.8409 - holdout_precision_1: 0.8051 - holdout_recall_1: 0.9330 - holdout_f1_1: 0.8643 - holdout_roc_auc: 0.9422 - holdout_ap: 0.9581
# Epoch 4/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 4: Holdout Precision (Class 0) = 0.8581, Recall (Class 0) = 0.9275, F1 (Class 0) = 0.8914
# Epoch 4: Holdout Precision (Class 1) = 0.9211, Recall (Class 1) = 0.8466, F1 (Class 1) = 0.8823
# Epoch 4: Holdout ROC-AUC Score = 0.9425, Average Precision (AP) Score = 0.9573
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 145ms/step - accuracy: 0.6418 - loss: 0.7168 - roc_auc: 0.7027 - val_accuracy: 0.7576 - val_loss: 0.5921 - val_roc_auc: 0.8115 - holdout_precision_0: 0.8581 - holdout_recall_0: 0.9275 - holdout_f1_0: 0.8914 - holdout_precision_1: 0.9211 - holdout_recall_1: 0.8466 - holdout_f1_1: 0.8823 - holdout_roc_auc: 0.9425 - holdout_ap: 0.9573
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
# L2 = 0.03854, epochs = 4: ROC-AUC = 0.9425, F1 (Class 0) = 0.8914, F1 (Class 1) = 0.8823, AP score = 0.9573, Average F1 Score = 0.8869
# Testing L2 = 0.03855, epochs = 3
# Epoch 1/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.9260, Recall (Class 0) = 0.4711, F1 (Class 0) = 0.6245
# Epoch 1: Holdout Precision (Class 1) = 0.6453, Recall (Class 1) = 0.9624, F1 (Class 1) = 0.7726
# Epoch 1: Holdout ROC-AUC Score = 0.9351, Average Precision (AP) Score = 0.9435
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 51s 183ms/step - accuracy: 0.5245 - loss: 2.1270 - roc_auc: 0.5258 - val_accuracy: 0.6101 - val_loss: 0.6978 - val_roc_auc: 0.7139 - holdout_precision_0: 0.9260 - holdout_recall_0: 0.4711 - holdout_f1_0: 0.6245 - holdout_precision_1: 0.6453 - holdout_recall_1: 0.9624 - holdout_f1_1: 0.7726 - holdout_roc_auc: 0.9351 - holdout_ap: 0.9435
# Epoch 2/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.8968, Recall (Class 0) = 0.8457, F1 (Class 0) = 0.8705
# Epoch 2: Holdout Precision (Class 1) = 0.8540, Recall (Class 1) = 0.9027, F1 (Class 1) = 0.8777
# Epoch 2: Holdout ROC-AUC Score = 0.9346, Average Precision (AP) Score = 0.9476
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.5789 - loss: 0.8989 - roc_auc: 0.6066 - val_accuracy: 0.7197 - val_loss: 0.6522 - val_roc_auc: 0.7673 - holdout_precision_0: 0.8968 - holdout_recall_0: 0.8457 - holdout_f1_0: 0.8705 - holdout_precision_1: 0.8540 - holdout_recall_1: 0.9027 - holdout_f1_1: 0.8777 - holdout_roc_auc: 0.9346 - holdout_ap: 0.9476
# Epoch 3/3
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.8975, Recall (Class 0) = 0.8760, F1 (Class 0) = 0.8866
# Epoch 3: Holdout Precision (Class 1) = 0.8789, Recall (Class 1) = 0.8999, F1 (Class 1) = 0.8893
# Epoch 3: Holdout ROC-AUC Score = 0.9428, Average Precision (AP) Score = 0.9529
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 145ms/step - accuracy: 0.6190 - loss: 0.7833 - roc_auc: 0.6621 - val_accuracy: 0.7323 - val_loss: 0.6286 - val_roc_auc: 0.7857 - holdout_precision_0: 0.8975 - holdout_recall_0: 0.8760 - holdout_f1_0: 0.8866 - holdout_precision_1: 0.8789 - holdout_recall_1: 0.8999 - holdout_f1_1: 0.8893 - holdout_roc_auc: 0.9428 - holdout_ap: 0.9529
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
# L2 = 0.03855, epochs = 3: ROC-AUC = 0.9428, F1 (Class 0) = 0.8866, F1 (Class 1) = 0.8893, AP score = 0.9529, Average F1 Score = 0.8880
# Testing L2 = 0.03855, epochs = 4
# Epoch 1/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.8485, Recall (Class 0) = 0.8026, F1 (Class 0) = 0.8249
# Epoch 1: Holdout Precision (Class 1) = 0.8127, Recall (Class 1) = 0.8567, F1 (Class 1) = 0.8342
# Epoch 1: Holdout ROC-AUC Score = 0.8946, Average Precision (AP) Score = 0.9133
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 49s 177ms/step - accuracy: 0.5397 - loss: 1.7765 - roc_auc: 0.5526 - val_accuracy: 0.6697 - val_loss: 0.6775 - val_roc_auc: 0.7124 - holdout_precision_0: 0.8485 - holdout_recall_0: 0.8026 - holdout_f1_0: 0.8249 - holdout_precision_1: 0.8127 - holdout_recall_1: 0.8567 - holdout_f1_1: 0.8342 - holdout_roc_auc: 0.8946 - holdout_ap: 0.9133
# Epoch 2/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.8356, Recall (Class 0) = 0.7934, F1 (Class 0) = 0.8139
# Epoch 2: Holdout Precision (Class 1) = 0.8033, Recall (Class 1) = 0.8439, F1 (Class 1) = 0.8231
# Epoch 2: Holdout ROC-AUC Score = 0.8895, Average Precision (AP) Score = 0.8954
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 143ms/step - accuracy: 0.5817 - loss: 0.9082 - roc_auc: 0.6163 - val_accuracy: 0.6760 - val_loss: 0.6606 - val_roc_auc: 0.7417 - holdout_precision_0: 0.8356 - holdout_recall_0: 0.7934 - holdout_f1_0: 0.8139 - holdout_precision_1: 0.8033 - holdout_recall_1: 0.8439 - holdout_f1_1: 0.8231 - holdout_roc_auc: 0.8895 - holdout_ap: 0.8954
# Epoch 3/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
#
# Epoch 3: Holdout Precision (Class 0) = 0.8445, Recall (Class 0) = 0.7980, F1 (Class 0) = 0.8206
# Epoch 3: Holdout Precision (Class 1) = 0.8085, Recall (Class 1) = 0.8531, F1 (Class 1) = 0.8302
# Epoch 3: Holdout ROC-AUC Score = 0.8989, Average Precision (AP) Score = 0.9140
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 41s 143ms/step - accuracy: 0.6065 - loss: 0.7906 - roc_auc: 0.6434 - val_accuracy: 0.7466 - val_loss: 0.6305 - val_roc_auc: 0.7962 - holdout_precision_0: 0.8445 - holdout_recall_0: 0.7980 - holdout_f1_0: 0.8206 - holdout_precision_1: 0.8085 - holdout_recall_1: 0.8531 - holdout_f1_1: 0.8302 - holdout_roc_auc: 0.8989 - holdout_ap: 0.9140
# Epoch 4/4
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step
#
# Epoch 4: Holdout Precision (Class 0) = 0.8528, Recall (Class 0) = 0.9366, F1 (Class 0) = 0.8928
# Epoch 4: Holdout Precision (Class 1) = 0.9297, Recall (Class 1) = 0.8384, F1 (Class 1) = 0.8817
# Epoch 4: Holdout ROC-AUC Score = 0.9306, Average Precision (AP) Score = 0.9382
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 34s 144ms/step - accuracy: 0.6472 - loss: 0.7192 - roc_auc: 0.7077 - val_accuracy: 0.7719 - val_loss: 0.5795 - val_roc_auc: 0.8305 - holdout_precision_0: 0.8528 - holdout_recall_0: 0.9366 - holdout_f1_0: 0.8928 - holdout_precision_1: 0.9297 - holdout_recall_1: 0.8384 - holdout_f1_1: 0.8817 - holdout_roc_auc: 0.9306 - holdout_ap: 0.9382
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step
# L2 = 0.03855, epochs = 4: ROC-AUC = 0.9306, F1 (Class 0) = 0.8928, F1 (Class 1) = 0.8817, AP score = 0.9382, Average F1 Score = 0.8872
# Best parameters: {'l2': 0.03851, 'epochs': 3}
# Best holdout metrics: Precision_0 = 0.9273, Recall_0 = 0.8907, Precision_1 = 0.8949, Recall_1 = 0.9302, F1_0 = 0.9087, F1_1 = 0.9122, AP score = 0.9588

# %%
best_model = load_model('/content/wids_gs_best_mod.keras')

# %%
best_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 300)                 │       7,526,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 300)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 200)                 │          60,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 200)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 100)                 │          20,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 25)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 82,913,207 (316.29 MB)
#  Trainable params: 27,637,735 (105.43 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 55,275,472 (210.86 MB)

# %%
with open('wids_gs_best_train_history.json', 'r') as f:
    best_history = json.load(f)

# %%
best_history
# Out:
# {'accuracy': [0.5631093382835388, 0.6005269885063171, 0.6420289874076843],
#  'loss': [1.1651498079299927, 0.7971414923667908, 0.7214199304580688],
#  'roc_auc': [0.5896376371383667, 0.6493446230888367, 0.6969356536865234],
#  'val_accuracy': [0.6612223386764526, 0.694942057132721, 0.739199161529541],
#  'val_loss': [0.6829479336738586, 0.6604640483856201, 0.6202337145805359],
#  'val_roc_auc': [0.7188954949378967, 0.7597310543060303, 0.803413450717926],
#  'holdout_precision_0': [0.8493317132442284,
#   0.8928974069898534,
#   0.9273422562141491],
#  'holdout_recall_0': [0.6418732782369146,
#   0.7272727272727273,
#   0.8907254361799817],
#  'holdout_f1_0': [0.7311715481171548, 0.8016194331983806, 0.9086651053864169],
#  'holdout_precision_1': [0.7121771217712177,
#   0.7699457784663052,
#   0.8948763250883393],
#  'holdout_recall_1': [0.8861340679522498,
#   0.9127640036730946,
#   0.9302112029384757],
#  'holdout_f1_1': [0.7896890343698855, 0.8352941176470589, 0.9122017109410175],
#  'holdout_roc_auc': [0.88600716236579, 0.9205587893291374, 0.954517206458103],
#  'holdout_ap': [0.895211486771686, 0.9363129603528938, 0.9588121803641274]}

# %%
# Plot training and validation loss. Note that the values are stored as a dictionary,
# so we need to access them like so
loss = best_history["loss"]
val_loss = best_history["val_loss"]
epochs = range(1, len(loss) + 1) # Because counting from 0

# %%
plt.figure(figsize=(8, 6))
plt.plot(epochs, loss, marker = 'o', label = "Training Loss")
plt.plot(epochs, val_loss, marker = 'o', label = "Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
ap_scores_ho = best_history['holdout_ap']
plt.plot(epochs, ap_scores_ho, marker = 'o', label = "AP score")
plt.title("Average Precision (AP) Scores Per Epoch")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("AP Score")
plt.ylim(0.5, 1.0)  # For clear scaling
plt.legend()
plt.show()

# %%
roc_auc_scores = best_history['holdout_roc_auc']

# %%
plt.plot(epochs, roc_auc_scores, marker='o', label='ROC-AUC (Holdout)')
plt.title('ROC-AUC per Epoch')
plt.xlabel('Epochs')
plt.ylabel('ROC-AUC Score')
plt.xticks(epochs)
plt.ylim(0.5, 1.0)  # For clear scaling
plt.legend()
plt.show()

# %%
x_ho, y_ho = ho_dataset

# %%
predicted_probs = best_model.predict(x_ho).ravel()
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step

# %%
roc_auc_score_ho = roc_auc_score(y_ho, predicted_probs)
roc_auc_score_ho
# Out:
# 0.954517206458103

# %%
# Calculate precision-recall pairs for different thresholds
precision, recall, thresholds = precision_recall_curve(y_ho, predicted_probs)

# Compute the area under the curve (AUC)
pr_auc = auc(recall, precision)
pr_auc
# Out:
# 0.9587829433371764

# %%
# Plot the precision-recall curve
plt.figure(figsize = (8, 6))
plt.plot(recall, precision, label = f'PR Curve (AUC = {pr_auc:.4f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc ='lower left')
plt.show()

# %%
# Compute false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_ho, predicted_probs)

# Compute the ROC AUC score
roc_auc = roc_auc_score(y_ho, predicted_probs)
roc_auc
# Out:
# 0.954517206458103

# %%
# Plot the ROC curve
plt.figure(figsize = (8, 6))
plt.plot(fpr, tpr, label = f'ROC Curve (AUC = {roc_auc:.4f})', color = 'dodgerblue')
plt.plot([0, 1], [0, 1], linestyle = '--', color = 'gray', label = 'Chance Level (AUC = 0.5)')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc = 'lower right')
plt.show()

# %%
preds = (predicted_probs > 0.5).astype(int)

# %%
conf_matrix = confusion_matrix(y_ho, preds)

# %%
print(classification_report(y_ho, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      1089
#            1       0.89      0.93      0.91      1089
#
#     accuracy                           0.91      2178
#    macro avg       0.91      0.91      0.91      2178
# weighted avg       0.91      0.91      0.91      2178

# %%
class_names = ['Negative', 'Positive']

# Plot the confusion matrix
plt.figure(figsize = (8, 6))
sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = 'Blues', xticklabels = class_names, yticklabels = class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Normalize the confusion matrix
conf_matrix_normalized = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# Plot the normalized confusion matrix
plt.figure(figsize = (8, 6))
sns.heatmap(conf_matrix_normalized, annot = True, fmt = '.2f', cmap = 'Blues', xticklabels = class_names, yticklabels = class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix')
plt.show()

# %% [markdown]
# We will download our results after the end of our modeling / analysis.

# %%
files.download('/content/wids_gs_best_train_history.json')
files.download('/content/wids_gs_results.csv')
files.download('/content/wids_gs_best_mod.keras')

# %% [markdown]
# # **Fine Tuning**

# %%
# Define the same custom callback but separately for fine tuning
class PrecisionRecallHoldoutCallback_tuned(tf.keras.callbacks.Callback):
    def __init__(self, holdout_data):
        self.holdout_data = holdout_data  # Holdout data (X, y)
        self.precision_0 = []
        self.recall_0 = []
        self.f1_0 = []  # F1 score for Class 0
        self.precision_1 = []
        self.recall_1 = []
        self.f1_1 = []  # F1 score for Class 1
        self.roc_auc_scores = []  # ROC-AUC scores across epochs
        self.ap_scores = [] # AP scores across epochs

    def on_epoch_end(self, epoch, logs=None):
        x_holdout, y_holdout = self.holdout_data
        predictions = self.model.predict(x_holdout).ravel() # Flatten out
        predictions_binary = (predictions > 0.5).astype(int)  # Convert probabilities to binary predictions

        # Compute metrics for Class 0
        precision_0 = precision_score(y_holdout, predictions_binary, pos_label=0)
        recall_0 = recall_score(y_holdout, predictions_binary, pos_label=0)
        f1_0 = f1_score(y_holdout, predictions_binary, pos_label=0)

        # Compute metrics for Class 1
        precision_1 = precision_score(y_holdout, predictions_binary, pos_label=1)
        recall_1 = recall_score(y_holdout, predictions_binary, pos_label=1)
        f1_1 = f1_score(y_holdout, predictions_binary, pos_label=1)

        # Compute ROC-AUC score
        roc_auc = roc_auc_score(y_holdout, predictions)
        # Compute Average Precision (AP) score
        ap_score = average_precision_score(y_holdout, predictions)

        # Log metrics
        print(f"\nEpoch {epoch + 1}: Holdout Precision (Class 0) = {precision_0:.4f}, Recall (Class 0) = {recall_0:.4f}, F1 (Class 0) = {f1_0:.4f}")
        print(f"Epoch {epoch + 1}: Holdout Precision (Class 1) = {precision_1:.4f}, Recall (Class 1) = {recall_1:.4f}, F1 (Class 1) = {f1_1:.4f}")
        print(f"Epoch {epoch + 1}: Holdout ROC-AUC Score = {roc_auc:.4f}, Average Precision (AP) Score = {ap_score:.4f}")

        # Append metrics to lists
        self.precision_0.append(precision_0)
        self.recall_0.append(recall_0)
        self.f1_0.append(f1_0)
        self.precision_1.append(precision_1)
        self.recall_1.append(recall_1)
        self.f1_1.append(f1_1)
        self.roc_auc_scores.append(roc_auc)
        self.ap_scores.append(ap_score)

        # Optionally store metrics in logs for further analysis
        logs['holdout_precision_0'] = precision_0
        logs['holdout_recall_0'] = recall_0
        logs['holdout_f1_0'] = f1_0
        logs['holdout_precision_1'] = precision_1
        logs['holdout_recall_1'] = recall_1
        logs['holdout_f1_1'] = f1_1
        logs['holdout_roc_auc'] = roc_auc
        logs['holdout_ap'] = ap_score

# %% [markdown]
# We will train our saved model for two additional epochs but at a lower learning rate.

# %%
best_score_tuned = None
best_params_tuned = None
best_history_tuned = None
best_metrics_tuned = None
results_tuned = []

for layer in best_model.layers:
  layer.trainable = True

# Compile
best_model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate = 1e-5, weight_decay = 5e-5),
            loss='binary_crossentropy',
            metrics=['accuracy', tf.keras.metrics.AUC(name='roc_auc', curve='ROC')])

# Train
holdout_callback_tuned = PrecisionRecallHoldoutCallback_tuned((x_holdout, y_holdout))
history_tuned = best_model.fit(
  train_dataset,
  epochs=2,
  validation_data=val_dataset,
  callbacks=[holdout_callback_tuned],
  verbose=1
)

# Evaluate
roc_auc_score_ho = holdout_callback_tuned.roc_auc_scores[-1]
ap_score = holdout_callback_tuned.ap_scores[-1]
f1_class_0 = holdout_callback_tuned.f1_0[-1]
f1_class_1 = holdout_callback_tuned.f1_1[-1]
avg_f1_score = (f1_class_0 + f1_class_1) / 2


x_holdout, y_holdout = ho_dataset
predictions = model.predict(x_holdout)
predictions = (predictions > 0.5).astype(int)

precision_0 = precision_score(y_holdout, predictions, pos_label=0)
recall_0 = recall_score(y_holdout, predictions, pos_label=0)

precision_1 = precision_score(y_holdout, predictions, pos_label=1)
recall_1 = recall_score(y_holdout, predictions, pos_label=1)

print(f"ROC-AUC = {roc_auc_score_ho:.4f}, "
    f"F1 (Class 0) = {f1_class_0:.4f}, F1 (Class 1) = {f1_class_1:.4f}, "
    f"AP score = {ap_score:.4f}, "
    f"Average F1 Score = {avg_f1_score:.4f}")

# Append results
results_tuned.append({
  'roc_auc': roc_auc_score_ho,
  'ap_score': ap_score,
  'f1_class_0': f1_class_0,
  'f1_class_1': f1_class_1,
  'avg_f1_score': avg_f1_score,
  'precision_0': precision_0,
  'recall_0': recall_0,
  'precision_1': precision_1,
  'recall_1': recall_1
})

# Track best metrics
if best_score_tuned is None or avg_f1_score > best_score_tuned:
  print("\nUpdating best model.\n")
  best_score_tuned = avg_f1_score
  best_metrics_tuned = [precision_0, recall_0, precision_1, recall_1, f1_class_0, f1_class_1, ap_score]
  best_history_tuned = history_tuned.history  # Save the training history of the best model
  best_model.save('wids_gs_best_mod_tuned.keras')  # Save the best model

# Clear session
tf.keras.backend.clear_session()

# Save results and best history
pd.DataFrame(results_tuned).to_csv('wids_gs_results_tuned.csv', index=False)
with open('wids_gs_best_train_history_tuned.json', 'w') as f:
  json.dump(best_history_tuned, f)

print(f"Best holdout metrics: Precision_0 = {best_metrics_tuned[0]:.4f}, Recall_0 = {best_metrics_tuned[1]:.4f}, "
    f"Precision_1 = {best_metrics_tuned[2]:.4f}, Recall_1 = {best_metrics_tuned[3]:.4f}, "
    f"F1_0 = {best_metrics_tuned[4]:.4f}, F1_1 = {best_metrics_tuned[5]:.4f}, "
    f"AP score = {best_metrics_tuned[6]:.4f}")
# Out:
# Epoch 1/2
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step
#
# Epoch 1: Holdout Precision (Class 0) = 0.9048, Recall (Class 0) = 0.8898, F1 (Class 0) = 0.8972
# Epoch 1: Holdout Precision (Class 1) = 0.8916, Recall (Class 1) = 0.9063, F1 (Class 1) = 0.8989
# Epoch 1: Holdout ROC-AUC Score = 0.9599, Average Precision (AP) Score = 0.9613
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 103s 376ms/step - accuracy: 0.6617 - loss: 0.6630 - roc_auc: 0.7237 - val_accuracy: 0.7476 - val_loss: 0.5901 - val_roc_auc: 0.7903 - holdout_precision_0: 0.9048 - holdout_recall_0: 0.8898 - holdout_f1_0: 0.8972 - holdout_precision_1: 0.8916 - holdout_recall_1: 0.9063 - holdout_f1_1: 0.8989 - holdout_roc_auc: 0.9599 - holdout_ap: 0.9613
# Epoch 2/2
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step
#
# Epoch 2: Holdout Precision (Class 0) = 0.9008, Recall (Class 0) = 0.9421, F1 (Class 0) = 0.9210
# Epoch 2: Holdout Precision (Class 1) = 0.9394, Recall (Class 1) = 0.8962, F1 (Class 1) = 0.9173
# Epoch 2: Holdout ROC-AUC Score = 0.9701, Average Precision (AP) Score = 0.9721
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 81s 339ms/step - accuracy: 0.7078 - loss: 0.5999 - roc_auc: 0.7699 - val_accuracy: 0.7534 - val_loss: 0.5656 - val_roc_auc: 0.8015 - holdout_precision_0: 0.9008 - holdout_recall_0: 0.9421 - holdout_f1_0: 0.9210 - holdout_precision_1: 0.9394 - holdout_recall_1: 0.8962 - holdout_f1_1: 0.9173 - holdout_roc_auc: 0.9701 - holdout_ap: 0.9721
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step
# ROC-AUC = 0.9701, F1 (Class 0) = 0.9210, F1 (Class 1) = 0.9173, AP score = 0.9721, Average F1 Score = 0.9191
#
# Updating best model.
#
# Best holdout metrics: Precision_0 = 0.8528, Recall_0 = 0.9366, Precision_1 = 0.9297, Recall_1 = 0.8384, F1_0 = 0.9210, F1_1 = 0.9173, AP score = 0.9721

# %%
best_model_tuned = load_model('/content/wids_gs_best_mod_tuned.keras')

# %%
best_model_tuned.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 300)                 │       7,526,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 300)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 200)                 │          60,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 200)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 100)                 │          20,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 25)                  │           1,275 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 25)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 82,913,207 (316.29 MB)
#  Trainable params: 27,637,735 (105.43 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 55,275,472 (210.86 MB)

# %%
with open('wids_gs_best_train_history_tuned.json', 'r') as f:
    best_history_tuned_loaded = json.load(f)

# %%
best_history_tuned_loaded
# Out:
# {'accuracy': [0.6772068738937378, 0.7143610119819641],
#  'loss': [0.6420944333076477, 0.5886056423187256],
#  'roc_auc': [0.7397038340568542, 0.7777901291847229],
#  'val_accuracy': [0.7476291060447693, 0.7534246444702148],
#  'val_loss': [0.590070903301239, 0.5655796527862549],
#  'val_roc_auc': [0.7903310656547546, 0.8014987111091614],
#  'holdout_precision_0': [0.9047619047619048, 0.9007901668129938],
#  'holdout_recall_0': [0.8898071625344353, 0.9421487603305785],
#  'holdout_f1_0': [0.8972222222222223, 0.9210053859964094],
#  'holdout_precision_1': [0.8915989159891599, 0.9393647738209817],
#  'holdout_recall_1': [0.90633608815427, 0.8962350780532599],
#  'holdout_f1_1': [0.8989071038251366, 0.9172932330827067],
#  'holdout_roc_auc': [0.9598902456403083, 0.9701480958681058],
#  'holdout_ap': [0.9613475389718612, 0.9721394468742387]}

# %%
loss_tuned = best_history_tuned_loaded['loss']
val_loss_tuned = best_history_tuned_loaded['val_loss']
epochs_tuned = range(1, len(loss_tuned) + 1)

# %%
# Plot training and validation losses, fine tuned
plt.figure(figsize=(8, 6))
plt.plot(epochs_tuned, loss_tuned, marker = 'o', label = "Training Loss")
plt.plot(epochs_tuned, val_loss_tuned, marker = 'o', label = "Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.xticks(epochs_tuned)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Plot AP scores per epoch, fine tuned
ap_scores_ho_tuned = best_history_tuned_loaded['holdout_ap']
plt.plot(epochs_tuned, ap_scores_ho_tuned, marker = 'o', label = "AP score")
plt.title("Average Precision (AP) Scores Per Epoch, Fine Tuned")
plt.xlabel("Epochs")
plt.xticks(epochs_tuned)
plt.ylabel("AP Score")
plt.legend()
plt.show()

# %%
roc_auc_scores_tuned = best_history_tuned['holdout_roc_auc']

# %%
# Plot ROC-AUC per Epoch, fine tuned
plt.plot(epochs_tuned, roc_auc_scores_tuned, marker='o', label='ROC-AUC (Holdout)')
plt.title('ROC-AUC per Epoch')
plt.xlabel('Epochs')
plt.ylabel('ROC-AUC Score')
plt.xticks(epochs_tuned)
plt.legend()
plt.show()

# %%
predicted_probs_tuned = best_model_tuned.predict(x_ho).ravel()
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step

# %%
roc_auc_score_ho_tuned = roc_auc_score(y_ho, predicted_probs_tuned)
roc_auc_score_ho_tuned
# Out:
# 0.9701480958681058

# %%
# Calculate precision-recall pairs for different thresholds, fine tuned
precision_tuned, recall_tuned, thresholds_tuned = precision_recall_curve(y_ho, predicted_probs_tuned)

# Compute the area under the curve (AUC), fine tuned
pr_auc_tuned = auc(recall_tuned, precision_tuned)
pr_auc_tuned
# Out:
# 0.9721254913314007

# %%
# Plot the precision-recall curve, fine tuned
plt.figure(figsize = (8, 6))
plt.plot(recall_tuned, precision_tuned, label = f'PR Curve (AUC = {pr_auc_tuned:.4f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc ='lower left')
plt.show()

# %%
# Compute false positive rate, true positive rate, and thresholds, fine tuned
fpr_tuned, tpr_tuned, thresholds_tuned = roc_curve(y_ho, predicted_probs_tuned)

# Compute the ROC AUC score, fine tuned
roc_auc_tuned = roc_auc_score(y_ho, predicted_probs_tuned)
roc_auc_tuned
# Out:
# 0.9701480958681058

# %%
# Plot the ROC curve, fine tuned
plt.figure(figsize = (8, 6))
plt.plot(fpr_tuned, tpr_tuned, label = f'ROC Curve (AUC = {roc_auc_tuned:.4f})', color = 'dodgerblue')
plt.plot([0, 1], [0, 1], linestyle = '--', color = 'gray', label = 'Chance Level (AUC = 0.5)')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc = 'lower right')
plt.show()

# %%
preds_tuned = (predicted_probs_tuned > 0.5).astype(int)

# %%
conf_matrix_tuned = confusion_matrix(y_ho, preds_tuned)

# %%
print(classification_report(y_ho, preds_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      1089
#            1       0.94      0.90      0.92      1089
#
#     accuracy                           0.92      2178
#    macro avg       0.92      0.92      0.92      2178
# weighted avg       0.92      0.92      0.92      2178

# %%
# Plot the confusion matrix, fine tuned
plt.figure(figsize = (8, 6))
sns.heatmap(conf_matrix_tuned, annot = True, fmt = 'd', cmap = 'Blues', xticklabels = class_names, yticklabels = class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Normalize the confusion matrix, fine tuned
conf_matrix_normalized_tuned = conf_matrix_tuned.astype('float') / conf_matrix_tuned.sum(axis=1)[:, np.newaxis]

# Plot the normalized confusion matrix, fine tuned
plt.figure(figsize = (8, 6))
sns.heatmap(conf_matrix_normalized_tuned, annot = True, fmt = '.2f', cmap = 'Blues', xticklabels = class_names, yticklabels = class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Normalized Confusion Matrix')
plt.show()

# %% [markdown]
# We will plot several metrics of our trained model but instead throughout all 5 epochs.

# %%
loss_total = loss + loss_tuned
val_loss_total = val_loss + val_loss_tuned
epochs_total = range(1, len(loss_total) + 1)

# %%
roc_auc_scores_total = roc_auc_scores + roc_auc_scores_tuned
ap_scores_total = ap_scores_ho + ap_scores_ho_tuned

# %%
plt.figure(figsize=(8, 6))
plt.plot(epochs_total, loss_total, marker = 'o', label = "Training Loss")
plt.plot(epochs_total, val_loss_total, marker = 'o', label = "Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.xticks(epochs_total)
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.plot(epochs_total, ap_scores_total, marker = 'o', label = "AP score")
plt.title("Average Precision (AP) Scores Per Epoch")
plt.xlabel("Epochs")
plt.xticks(epochs_total)
plt.ylabel("AP Score")
plt.legend()
plt.show()

# %%
plt.plot(epochs_total, roc_auc_scores_total, marker='o', label='ROC-AUC (Holdout)')
plt.title('ROC-AUC per Epoch')
plt.xlabel('Epochs')
plt.ylabel('ROC-AUC Score')
plt.xticks(epochs_total)
plt.legend()
plt.show()
